# %%
import numpy as np
import pandas as pd
import joblib
from tqdm.auto import tqdm
# EDA
import matplotlib.pyplot as plt
from IPython.display import display

# %%
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('dataset/trainingData_Spain.csv')
df.head()
# Out:
#        ID credit_status annual_income   verification_status  \
# 0  343480          Paid         24000              Verified
# 1  424837       Default         30000  Verified from source
# 2  890229          Paid         12252          Not Verified
# 3  527512          Paid         49200  Verified from source
# 4  968072          Paid         80000  Verified from source
#
#   employment_duration property_type interest_rate credit_amount  \
# 0           10+ years        Leased        10.65%          5000
# 1            < 1 year        Leased        15.27%          2500
# 2           10+ years        Rented        15.96%          2400
# 3           10+ years        Leased        13.49%         10000
# 4              1 year        Leased        12.69%          3000
#
#       credit_type        term credit_category
# 0     Credit card   36 months               B
# 1             car   60 months               C
# 2  Small business   36 months               C
# ...

# %%
profile = ProfileReport(df, title='Bank Sample Dataset', html={'style':{'full_width': True}}, dark_mode=True)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-09 06:20:33.755264&quot;&gt;&lt;title&gt;Bank Sample Dataset&lt;/title&gt;&lt;style&gt;
# @import url(&quot;https://fonts.googleapis.com/css?family=Lato:400,700,400italic&quot;);/*!
#  * bootswatch v3.3.7
#  * Homepage: http://bootswatch.com
#  * Copyright 2012-2016 Thomas Park
#  * Licensed under MIT
#  * Based on Bootstrap
# *//*!
# ...
